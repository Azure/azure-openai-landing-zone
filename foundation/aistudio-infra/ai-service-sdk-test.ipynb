# %%
#%pip install azure-ai-resources
#%pip install azure-identity
# Out:
# ...
#
# ...
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# ...
#   Using cached marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached jsonschema-4.20.0-py3-none-any.whl.metadata (8.1 kB)
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached strictyaml-1.7.3-py3-none-any.whl (123 kB)
# ...
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# ...
#      ---------------------------------------- 0.0/45.6 kB ? eta -:--:--
#      ---------------------------------------- 45.6/45.6 kB 2.4 MB/s eta 0:00:00
# ...
#   Using cached pydash-7.0.5-py3-none-any.whl.metadata (45 kB)
# ...
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# ...
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# ...

# %%
from azure.ai.resources.client import AIClient
from azure.identity import DefaultAzureCredential

ai_client = AIClient(credential=DefaultAzureCredential(), subscription_id='f1a8fafd-a8a3-46d8-bb5e-01deb63d275d',
                     resource_group_name='test-azure-ai-rg')
# Out:
# Failed to integrate module: opencensus.ext.logging.trace
# No module named 'opencensus.ext.logging'
# Class AIClient: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
connections = ai_client.connections
